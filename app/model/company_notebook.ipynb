# %% [markdown]
# # JobSypder NLP Model Development :: Job Boards

# %% [markdown]
# # 1. Frame the Business Problem

# %% [markdown]
# ## 2. Download the Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_json('../scraper/company_data.json')
data.head(20)
# Out:
#                _id             name  \
# 0            _pogo             Pogo
# 1        _greylock         Greylock
# 2          _replit           Replit
# 3      _mojovision      Mojo Vision
# 4       _dashbotio       dashbot.io
# 5           _tavus            Tavus
# 6             _hex              Hex
# 7           _clerk            Clerk
# 8          _openai           OpenAI
# 9       _replicate        Replicate
# 10      _quelltech       Quell Tech
# 11      _minogames       Mino Games
# 12  _lightfieldlab  Light Field Lab
# 13        _iggenix          IgGenix
# 14         _voldex           Voldex
# 15         _anyfin           Anyfin
# 16   _madstreetden   Mad Street Den
# 17          _deepl            DeepL
# 18            _wiz              Wiz
# 19   _memorahealth    Memora Health
#
#                                          company_link  \
# 0   https://www.joinpogo.com/?utm_source=topstartu...
# 1   https://greylock.com/portfolio/?utm_source=top...
# ...

# %% [markdown]
# ## 3. EDA

# %%
def get_domain(url):
    if (url):
        return url.split('://')[1].split('/')[0]
    else:
        return ""

data['job_board_domain'] = data['job_board'].apply(get_domain)
data['job_board_domain'].value_counts().head(20)
# Out:
# boards.greenhouse.io           350
# jobs.lever.co                  190
#                                 81
# jobs.ashbyhq.com                33
# apply.workable.com              28
# angel.co                        11
# www.linkedin.com                 7
# www.comeet.com                   6
# careers.smartrecruiters.com      5
# www.workatastartup.com           4
# www.ycombinator.com              3
# www.welcometothejungle.com       2
# jobs.gohire.io                   2
# jobs.eu.lever.co                 2
# recruiterflow.com                2
# www.zumper.com                   1
# compasspathways.com              1
# careers.luko.eu                  1
# zinier.breezy.hr                 1
# gotenna.com                      1
# Name: job_board_domain, dtype: int64

# %%
# Out:
# 'www.dashbot.io'
